# %%
#Here we have to check the length of password by:
#1 Make sure that password length is greater or equal to 8
#2 make sure that password contains lowercase and uppercase characters
#3 make sure that password contains special characters such as !@#$%^&*()

# %%
def password_strength_checker(password):
    if len(password)<8:
        return False
    if not any(char.isdigit() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char in '!@#$%^&*()' for char in password):
        return False
    return True

# %%
password_strength_checker("VEERdesai@#$")
# Out:
# False

# %%
password_strength_checker("VEERdesai@#$212006")
# Out:
# True
